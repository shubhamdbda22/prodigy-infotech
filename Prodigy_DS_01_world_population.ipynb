# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
## Here we imported data from our local disk and stored in df variable
df = pd.read_csv(r"C:/Users/hp/OneDrive/Desktop/CDAC-DBDA/2024/prodigy_infotech/task1/API_SP.POP.TOTL_DS2_en_csv_v2_45183.csv")

# %%
df.head()
# Out:
#          Data Source World Development Indicators         Unnamed: 2  \
# 0                NaN                          NaN                NaN
# 1  Last Updated Date                   30-05-2024                NaN
# 2                NaN                          NaN                NaN
# 3       Country Name                 Country Code     Indicator Name
# 4              Aruba                          ABW  Population, total
#
#        Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3  Indicator Code      1960.0      1961.0      1962.0      1963.0      1964.0
# 4     SP.POP.TOTL     54608.0     55811.0     56682.0     57475.0     58178.0
#
#    Unnamed: 9  ...  Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  \
# ...

# %%
## Here we droped unecessary columns
df = df.drop(df.index[:3]).reset_index(drop=True)
df.columns =df.iloc[0]
df = df.drop(df.index[:1]).reset_index(drop=True)

# %%
df
# Out:
# 0                   Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
# 0   Indicator Code       1960.0       1961.0       1962.0       1963.0  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
df.drop(['Indicator Name', 'Indicator Code', 'Country Code'], axis = 1, inplace=True)
df.head()
# Out:
# 0                 Country Name       1960.0       1961.0       1962.0  \
# 0                        Aruba      54608.0      55811.0      56682.0
# 1  Africa Eastern and Southern  130692579.0  134169237.0  137835590.0
# 2                  Afghanistan    8622466.0    8790140.0    8969047.0
# 3   Africa Western and Central   97256290.0   99314028.0  101445032.0
# 4                       Angola    5357195.0    5441333.0    5521400.0
#
# 0       1963.0       1964.0       1965.0       1966.0       1967.0  \
# 0      57475.0      58178.0      58782.0      59291.0      59522.0
# 1  141630546.0  145605995.0  149742351.0  153955516.0  158313235.0
# 2    9157465.0    9355514.0    9565147.0    9783147.0   10010030.0
# 3  103667517.0  105959979.0  108336203.0  110798486.0  113319950.0
# 4    5599827.0    5673199.0    5736582.0    5787044.0    5827503.0
#
# 0       1968.0  ...       2014.0       2015.0       2016.0       2017.0  \
# ...

# %%
# Select data for world population (assuming "World" is the country name)
world_data = df[df['Country Name'] == 'World']

# %%
world_data
# Out:
# 0   Country Name        1960.0        1961.0        1962.0        1963.0  \
# 259        World  3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09
#
# 0          1964.0        1965.0        1966.0        1967.0        1968.0  \
# 259  3.260442e+09  3.328209e+09  3.398480e+09  3.468371e+09  3.540164e+09
#
# 0    ...        2014.0        2015.0        2016.0        2017.0  \
# 259  ...  7.317040e+09  7.403850e+09  7.490415e+09  7.576442e+09
#
# 0          2018.0        2019.0        2020.0        2021.0        2022.0  \
# 259  7.660371e+09  7.741775e+09  7.820206e+09  7.888306e+09  7.950947e+09
#
# 0    2023.0
# 259     NaN
#
# [1 rows x 65 columns]

# %%
world_data_df = world_data.melt(id_vars='Country Name', var_name='Year', value_name='Population')

# df.melt is the pandas function for unpivoting columns.
# id_vars='Country Name': This argument specifies the column to retain in each row of the unpivoted DataFrame. Here, we're keeping the "Country Name" column.
# var_name='Year': This argument renames the column containing the original column names (years in this case) to "Year" in the unpivoted DataFrame.
# value_name='Population': This argument renames the column containing the values from the original data to "Population" in the unpivoted DataFrame.

# %%
world_data_df.drop(['Country Name'], axis = 1, inplace=True)

# %%
world_data_df
# Out:
#       Year    Population
# 0   1960.0  3.031474e+09
# 1   1961.0  3.072422e+09
# 2   1962.0  3.126850e+09
# 3   1963.0  3.193429e+09
# 4   1964.0  3.260442e+09
# ..     ...           ...
# 59  2019.0  7.741775e+09
# 60  2020.0  7.820206e+09
# 61  2021.0  7.888306e+09
# 62  2022.0  7.950947e+09
# 63  2023.0           NaN
#
# [64 rows x 2 columns]

# %%
# Create the bar chart
plt.figure(figsize=(8, 5))  # Adjust figure size as needed
plt.bar(world_data_df['Year'], world_data_df['Population'])
plt.xlabel('Year')
plt.ylabel('Population (In Billions)')
plt.title('World Population (1960-2022)')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a faint grid for better visualization
plt.tight_layout()  # Adjust spacing between elements
# Display the chart
plt.show()
